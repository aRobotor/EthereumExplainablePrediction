# %%
# !pip install pandoc
import pandoc
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.3 MB/s eta 0:00:00
# ...
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33261 sha256=9e5148a85acaba0c91b9fb205749fa6a049772e90292c16bcef7dd464212e126
#   Stored in directory: /root/.cache/pip/wheels/76/27/c2/c26175310aadcb8741b77657a1bb49c50cc7d4cdbf9eee0005
# Successfully built pandoc
# ...

# %%
from ipywidgets import Widget

Widget.close_all()

# %%
# !jupyter nbconvert --to html "/content/drive/MyDrive/Colab Notebooks/NeuroNetwork.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/NeuroNetwork.ipynb to html
# [NbConvertApp] Writing 1420687 bytes to /content/drive/MyDrive/Colab Notebooks/NeuroNetwork.html

# %%
# !pandoc "/content/drive/MyDrive/Colab Notebooks/NeuroNetwork.html" -s -o NeuroNetwork.docx
